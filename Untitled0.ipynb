# %% [markdown]
# <a href="https://colab.research.google.com/github/Luan-Andrade/test/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
5+3-9
# Out:
# Hello World!
# 8
